# %% [markdown]
# # 시작

# %%
import os, csv, json, io, math
import ray
import tensorflow as tf
from tensorflow.keras.layers import Add, Concatenate, Lambda
from tensorflow.keras.layers import Input, Conv2D, ReLU, MaxPool2D
from tensorflow.keras.layers import UpSampling2D, ZeroPadding2D
from tensorflow.keras.layers import BatchNormalization
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt

os.environ["CUDA_VISIBLE_DEVICES"] = '-1'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

PROJECT_PATH = os.getenv('HOME') + '/aiffel/mpii'
IMAGE_PATH = os.path.join(PROJECT_PATH, 'images')
TFRECORD_PATH = os.path.join(PROJECT_PATH, 'tfrecords_mpii')
TRAIN_JSON = os.path.join(PROJECT_PATH, 'mpii_human_pose_v1_u12_2', 'train.json')
VALID_JSON = os.path.join(PROJECT_PATH, 'mpii_human_pose_v1_u12_2', 'validation.json')

IMAGE_SHAPE = (256, 256, 3)
HEATMAP_SHAPE = (64, 64, 16)
# Out:
# /home/ssac5/anaconda3/envs/aiffel/lib/python3.7/site-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)

# %% [markdown]
# # TFRecord 준비

# %%
def chunkify(l, n):
    size = len(l) // n
    start = 0
    results = []
    for i in range(n - 1):
        results.append(l[start:start + size])
        start += size
    results.append(l[start:])
    return results


def _bytes_feature(value):
    if isinstance(value, type(tf.constant(0))):
        value = value.numpy()  
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))


def generate_tfexample(anno):
    filename = anno['filename']
    filepath = anno['filepath']
    with open(filepath, 'rb') as image_file:
        content = image_file.read()

    image = Image.open(filepath)
    if image.format != 'JPEG' or image.mode != 'RGB':
        image_rgb = image.convert('RGB')
        with io.BytesIO() as output:
            image_rgb.save(output, format="JPEG", quality=95)
            content = output.getvalue()

    width, height = image.size
    depth = 3

    c_x = int(anno['center'][0])
    c_y = int(anno['center'][1])
    scale = anno['scale']

    x = [
        int(joint[0]) if joint[0] >= 0 else int(joint[0])
        for joint in anno['joints']
    ]
    y = [
        int(joint[1]) if joint[1] >= 0 else int(joint[0])
        for joint in anno['joints']
    ]
    v = [0 if joint_v == 0 else 2 for joint_v in anno['joints_visibility']]

    feature = {
        'image/height':
        tf.train.Feature(int64_list=tf.train.Int64List(value=[height])),
        'image/width':
        tf.train.Feature(int64_list=tf.train.Int64List(value=[width])),
        'image/depth':
        tf.train.Feature(int64_list=tf.train.Int64List(value=[depth])),
        'image/object/parts/x':
        tf.train.Feature(int64_list=tf.train.Int64List(value=x)),
        'image/object/parts/y':
        tf.train.Feature(int64_list=tf.train.Int64List(value=y)),
        'image/object/center/x':
        tf.train.Feature(int64_list=tf.train.Int64List(value=[c_x])),
        'image/object/center/y':
        tf.train.Feature(int64_list=tf.train.Int64List(value=[c_y])),
        'image/object/scale':
        tf.train.Feature(float_list=tf.train.FloatList(value=[scale])),
        'image/object/parts/v':
        tf.train.Feature(int64_list=tf.train.Int64List(value=v)),
        'image/encoded':
        _bytes_feature(content),
        'image/filename':
        _bytes_feature(filename.encode())
    }

    return tf.train.Example(features=tf.train.Features(feature=feature))


@ray.remote
def build_single_tfrecord(chunk, path):
    with tf.io.TFRecordWriter(path) as writer:
        for anno_list in chunk:
            tf_example = generate_tfexample(anno_list)
            writer.write(tf_example.SerializeToString())


def build_tf_records(annotations, total_shards, split):
    chunks = chunkify(annotations, total_shards)
    futures = [
        build_single_tfrecord.remote(
            chunk, 
            '{}/{}_{}_of_{}.tfrecords'.format(
                TFRECORD_PATH,
                    split,
                    str(i + 1).zfill(4),
                    str(total_shards).zfill(4),
                )) for i, chunk in enumerate(chunks)
    ]
    ray.get(futures)


def parse_one_annotation(anno, image_dir):
    filename = anno['image']
    joints = anno['joints']
    joints_visibility = anno['joints_vis']
    annotation = {
        'filename': filename,
        'filepath': os.path.join(image_dir, filename),
        'joints_visibility': joints_visibility,
        'joints': joints,
        'center': anno['center'],
        'scale' : anno['scale']
    }
    return annotation

# %%
def make_trrecord():
    with open(TRAIN_JSON) as train_json:
        train_annos = json.load(train_json)
        train_annotations = [
            parse_one_annotation(anno, IMAGE_PATH)
            for anno in train_annos
        ]

    with open(TRAIN_JSON) as val_json:
        val_annos = json.load(val_json)
        val_annotations = [
            parse_one_annotation(anno, IMAGE_PATH) for anno in val_annos
        ]
        
    build_tf_records(train_annotations, 64, 'train')
    build_tf_records(val_annotations, 8, 'val')

# %% [markdown]
# # 데이터 전처리

# %%
class Preprocessor(object):
    def __init__(self,
                 image_shape=IMAGE_SHAPE,
                 heatmap_shape=HEATMAP_SHAPE,
                 is_train=False):
        self.is_train = is_train
        self.image_shape = image_shape
        self.heatmap_shape = heatmap_shape

    def __call__(self, example):
        features = self.parse_tfexample(example)
        image = tf.io.decode_jpeg(features['image/encoded'])

        if self.is_train:
            random_margin = tf.random.uniform([1], 0.1, 0.3)[0]
            image, keypoint_x, keypoint_y = self.crop_roi(image, features, margin=random_margin)
            image = tf.image.resize(image, self.image_shape[0:2])
        else:
            image, keypoint_x, keypoint_y = self.crop_roi(image, features)
            image = tf.image.resize(image, self.image_shape[0:2])

        image = tf.cast(image, tf.float32) / 127.5 - 1
        heatmaps = self.make_heatmaps(features, keypoint_x, keypoint_y)

        return image, heatmaps

    def parse_tfexample(self, example_proto):
        image_feature_description = {
            'image/height': tf.io.FixedLenFeature([], tf.int64),
            'image/width': tf.io.FixedLenFeature([], tf.int64),
            'imaage/depth': tf.io.FixedLenFeature([], tf.int64),
            'image/object/parts/x': tf.io.VarLenFeature(tf.int64),
            'image/object/parts/y': tf.io.VarLenFeature(tf.int64),
            'image/object/parts/v': tf.io.VarLenFeature(tf.int64),
            'image/object/center/x': tf.io.FixedLenFeature([], tf.int64),
            'image/object/center/y': tf.io.FixedLenFeature([], tf.int64),
            'image/object/scale': tf.io.FixedLenFeature([], tf.float32),
            'image/encoded': tf.io.FixedLenFeature([], tf.string),
            'image/filename': tf.io.FixedLenFeature([], tf.string),
        }
        return tf.io.parse_single_example(example_proto,
                                          image_feature_description)

    def crop_roi(self, image, features, margin=0.2):
        img_shape = tf.shape(image)
        img_height = img_shape[0]
        img_width = img_shape[1]
        img_depth = img_shape[2]

        keypoint_x = tf.cast(tf.sparse.to_dense(features['image/object/parts/x']), dtype=tf.int32)
        keypoint_y = tf.cast(tf.sparse.to_dense(features['image/object/parts/y']), dtype=tf.int32)
        center_x = features['image/object/center/x']
        center_y = features['image/object/center/y']
        body_height = features['image/object/scale'] * 200.0

        masked_keypoint_x = tf.boolean_mask(keypoint_x, keypoint_x > 0)
        masked_keypoint_y = tf.boolean_mask(keypoint_y, keypoint_y > 0)

        keypoint_xmin = tf.reduce_min(masked_keypoint_x)
        keypoint_xmax = tf.reduce_max(masked_keypoint_x)
        keypoint_ymin = tf.reduce_min(masked_keypoint_y)
        keypoint_ymax = tf.reduce_max(masked_keypoint_y)

        xmin = keypoint_xmin - tf.cast(body_height * margin, dtype=tf.int32)
        xmax = keypoint_xmax + tf.cast(body_height * margin, dtype=tf.int32)
        ymin = keypoint_ymin - tf.cast(body_height * margin, dtype=tf.int32)
        ymax = keypoint_ymax + tf.cast(body_height * margin, dtype=tf.int32)

        effective_xmin = xmin if xmin > 0 else 0
        effective_ymin = ymin if ymin > 0 else 0
        effective_xmax = xmax if xmax < img_width else img_width
        effective_ymax = ymax if ymax < img_height else img_height
        effective_height = effective_ymax - effective_ymin
        effective_width = effective_xmax - effective_xmin

        image = image[effective_ymin:effective_ymax, effective_xmin:effective_xmax, :]
        new_shape = tf.shape(image)
        new_height = new_shape[0]
        new_width = new_shape[1]

        effective_keypoint_x = (keypoint_x - effective_xmin) / new_width
        effective_keypoint_y = (keypoint_y - effective_ymin) / new_height

        return image, effective_keypoint_x, effective_keypoint_y

    def make_heatmaps(self, features, keypoint_x, keypoint_y):
        v = tf.cast(tf.sparse.to_dense(features['image/object/parts/v']), dtype=tf.float32)
        x = tf.cast(tf.math.round(keypoint_x * self.heatmap_shape[0]), dtype=tf.int32)
        y = tf.cast(tf.math.round(keypoint_y * self.heatmap_shape[1]), dtype=tf.int32)

        num_heatmap = self.heatmap_shape[2]
        heatmap_array = tf.TensorArray(tf.float32, 16)

        for i in range(num_heatmap):
            gaussian = self.generate_2d_guassian(self.heatmap_shape[1], self.heatmap_shape[0], y[i], x[i], v[i])
            heatmap_array = heatmap_array.write(i, gaussian)

        heatmaps = heatmap_array.stack()
        heatmaps = tf.transpose(heatmaps, perm=[1, 2, 0])

        return heatmaps

    def generate_2d_guassian(self, height, width, y0, x0, visibility=2, sigma=1, scale=12):
        heatmap = tf.zeros((height, width))

        xmin = x0 - 3 * sigma
        ymin = y0 - 3 * sigma
        xmax = x0 + 3 * sigma
        ymax = y0 + 3 * sigma
        
        if xmin >= width or ymin >= height or xmax < 0 or ymax < 0 or visibility == 0:
            return heatmap

        size = 6 * sigma + 1
        x, y = tf.meshgrid(tf.range(0, 6 * sigma + 1, 1), tf.range(0, 6 * sigma + 1, 1), indexing='xy')

        center_x = size // 2
        center_y = size // 2

        gaussian_patch = tf.cast(tf.math.exp(
            -(tf.square(x - center_x) + tf.math.square(y - center_y)) / (tf.math.square(sigma) * 2)) * scale,
                                 dtype=tf.float32)

        patch_xmin = tf.math.maximum(0, -xmin)
        patch_ymin = tf.math.maximum(0, -ymin)
        
        patch_xmax = tf.math.minimum(xmax, width) - xmin
        patch_ymax = tf.math.minimum(ymax, height) - ymin

        heatmap_xmin = tf.math.maximum(0, xmin)
        heatmap_ymin = tf.math.maximum(0, ymin)
        heatmap_xmax = tf.math.minimum(xmax, width)
        heatmap_ymax = tf.math.minimum(ymax, height)

        indices = tf.TensorArray(tf.int32, 1, dynamic_size=True)
        updates = tf.TensorArray(tf.float32, 1, dynamic_size=True)

        count = 0

        for j in tf.range(patch_ymin, patch_ymax):
            for i in tf.range(patch_xmin, patch_xmax):
                indices = indices.write(count, [heatmap_ymin + j, heatmap_xmin + i])
                updates = updates.write(count, gaussian_patch[j][i])
                count += 1

        heatmap = tf.tensor_scatter_nd_update(heatmap, indices.stack(), updates.stack())

        return heatmap

    def make_heatmaps(self, features, keypoint_x, keypoint_y):
        v = tf.cast(tf.sparse.to_dense(features['image/object/parts/v']), dtype=tf.float32)
        x = tf.cast(tf.math.round(keypoint_x * self.heatmap_shape[0]), dtype=tf.int32)
        y = tf.cast(tf.math.round(keypoint_y * self.heatmap_shape[1]), dtype=tf.int32)

        num_heatmap = self.heatmap_shape[2]
        heatmap_array = tf.TensorArray(tf.float32, 16)

        for i in range(num_heatmap):
            gaussian = self.generate_2d_guassian(self.heatmap_shape[1], self.heatmap_shape[0], y[i], x[i], v[i])
            heatmap_array = heatmap_array.write(i, gaussian)

        heatmaps = heatmap_array.stack()
        heatmaps = tf.transpose(heatmaps, perm=[1, 2, 0])

        return heatmaps

    def parse_tfexample(self, example_proto):
        image_feature_description = {
            'image/height': tf.io.FixedLenFeature([], tf.int64),
            'image/width': tf.io.FixedLenFeature([], tf.int64),
            'image/depth': tf.io.FixedLenFeature([], tf.int64),
            'image/object/parts/x': tf.io.VarLenFeature(tf.int64),
            'image/object/parts/y': tf.io.VarLenFeature(tf.int64),
            'image/object/parts/v': tf.io.VarLenFeature(tf.int64),
            'image/object/center/x': tf.io.FixedLenFeature([], tf.int64),
            'image/object/center/y': tf.io.FixedLenFeature([], tf.int64),
            'image/object/scale': tf.io.FixedLenFeature([], tf.float32),
            'image/encoded': tf.io.FixedLenFeature([], tf.string),
            'image/filename': tf.io.FixedLenFeature([], tf.string),
        }
        return tf.io.parse_single_example(example_proto,
                                          image_feature_description)

# %% [markdown]
# # 모델 생성

# %% [markdown]
# ## Hourglass

# %%
def BottleneckBlock(inputs, filters, strides=1, downsample=False, name=None):
    identity = inputs
    if downsample:
        identity = Conv2D(
            filters=filters,
            kernel_size=1,
            strides=strides,
            padding='same')(inputs)

    x = BatchNormalization(momentum=0.9)(inputs)
    x = ReLU()(x)
    x = Conv2D(
        filters=filters // 2,
        kernel_size=1,
        strides=1,
        padding='same')(x)

    x = BatchNormalization(momentum=0.9)(x)
    x = ReLU()(x)
    x = Conv2D(
        filters=filters // 2,
        kernel_size=3,
        strides=strides,
        padding='same')(x)

    x = BatchNormalization(momentum=0.9)(x)
    x = ReLU()(x)
    x = Conv2D(
        filters=filters,
        kernel_size=1,
        strides=1,
        padding='same')(x)

    x = Add()([identity, x])
    return x


def HourglassModule(inputs, order, filters, num_residual):
    up1 = BottleneckBlock(inputs, filters, downsample=False)

    for i in range(num_residual):
        up1 = BottleneckBlock(up1, filters, downsample=False)

    low1 = MaxPool2D(pool_size=2, strides=2)(inputs)
    for i in range(num_residual):
        low1 = BottleneckBlock(low1, filters, downsample=False)

    low2 = low1
    if order > 1:
        low2 = HourglassModule(low1, order - 1, filters, num_residual)
    else:
        for i in range(num_residual):
            low2 = BottleneckBlock(low2, filters, downsample=False)

    low3 = low2
    for i in range(num_residual):
        low3 = BottleneckBlock(low3, filters, downsample=False)

    up2 = UpSampling2D(size=2)(low3)

    return up2 + up1


def LinearLayer(inputs, filters):
    x = Conv2D(
        filters=filters,
        kernel_size=1,
        strides=1,
        padding='same')(inputs)
    x = BatchNormalization(momentum=0.9)(x)
    x = ReLU()(x)
    return x


def StackedHourglassNetwork(input_shape=IMAGE_SHAPE, num_stack=4,
                            num_residual=1, num_heatmap=16):
    inputs = Input(shape=input_shape)

    x = Conv2D(
        filters=64,
        kernel_size=7,
        strides=2,
        padding='same')(inputs)
    x = BatchNormalization(momentum=0.9)(x)
    x = ReLU()(x)
    x = BottleneckBlock(x, 128, downsample=True)
    x = MaxPool2D(pool_size=2, strides=2)(x)
    x = BottleneckBlock(x, 128, downsample=False)
    x = BottleneckBlock(x, 256, downsample=True)

    ys = []
    for i in range(num_stack):
        x = HourglassModule(x, order=4, filters=256, num_residual=num_residual)
        for i in range(num_residual):
            x = BottleneckBlock(x, 256, downsample=False)

        x = LinearLayer(x, 256)
        y = Conv2D(
            filters=num_heatmap,
            kernel_size=1,
            strides=1,
            padding='same')(x)
        ys.append(y)

        if i < num_stack - 1:
            y_intermediate_1 = Conv2D(filters=256, kernel_size=1, strides=1)(x)
            y_intermediate_2 = Conv2D(filters=256, kernel_size=1, strides=1)(y)
            x = Add()([y_intermediate_1, y_intermediate_2])

    return tf.keras.Model(inputs, ys, name='stacked_hourglass')

# %% [markdown]
# ## SimpleBaseline

# %%
def _make_deconv_layer(num_deconv_layers):
    seq_model = tf.keras.models.Sequential()

    for i in range(num_deconv_layers):
        seq_model.add(tf.keras.layers.Conv2DTranspose(256, kernel_size=(4,4), strides=(2,2), padding='same'))
        seq_model.add(tf.keras.layers.BatchNormalization())
        seq_model.add(tf.keras.layers.ReLU())

    return seq_model


def Simplebaseline(input_shape=IMAGE_SHAPE, num_heatmap=16):
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.applications.resnet.ResNet50(include_top=False, weights='imagenet')(inputs)
    x = _make_deconv_layer(3)(x)
    out = tf.keras.layers.Conv2D(num_heatmap, kernel_size=(1,1), padding='same')(x)
    model = tf.keras.Model(inputs, out, name='simple_baseline')
    return model

# %% [markdown]
# # 모델 훈련

# %%
def automatic_gpu_usage() :
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
        except RuntimeError as e:
            print(e)

# %% [markdown]
# ## Hourglass

# %%
class HGTrainer(object):
    def __init__(self,
                 model,
                 history,
                 epochs,
                 global_batch_size,
                 strategy,
                 initial_learning_rate):
        self.model = model
        self.history = history
        self.epochs = epochs
        self.strategy = strategy
        self.global_batch_size = global_batch_size
        self.loss_object = tf.keras.losses.MeanSquaredError(reduction=tf.keras.losses.Reduction.NONE)
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)

        self.current_learning_rate = initial_learning_rate
        self.last_val_loss = math.inf
        self.lowest_val_loss = math.inf
        self.patience_count = 0
        self.max_patience = 10
        self.best_model = None

    def lr_decay(self):
        if self.patience_count >= self.max_patience:
            self.current_learning_rate /= 10.0
            self.patience_count = 0
        elif self.last_val_loss == self.lowest_val_loss:
            self.patience_count = 0
        self.patience_count += 1
        self.optimizer.learning_rate = self.current_learning_rate

    def lr_decay_step(self, epoch):
        if epoch == 25 or epoch == 50 or epoch == 75:
            self.current_learning_rate /= 10.0
        self.optimizer.learning_rate = self.current_learning_rate

    def compute_loss(self, labels, outputs):
        if type(outputs)!=list:
            outputs = [outputs]
        loss = 0
        for output in outputs:
            weights = tf.cast(labels > 0, dtype=tf.float32) * 81 + 1
            loss += tf.math.reduce_mean(tf.math.square(labels - output) * weights) * (1. / self.global_batch_size)
        return loss

    def train_step(self, inputs):
        images, labels = inputs
        with tf.GradientTape() as tape:
            outputs = self.model(images, training=True)
            loss = self.compute_loss(labels, outputs)

        grads = tape.gradient(target=loss, sources=self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

        return loss

    def val_step(self, inputs):
        images, labels = inputs
        outputs = self.model(images, training=False)
        loss = self.compute_loss(labels, outputs)
        return loss

    def run(self, train_dist_dataset, val_dist_dataset):
        @tf.function
        def distributed_train_epoch(dataset):
            tf.print('Start distributed traininng...')
            total_loss = 0.0
            num_train_batches = 0.0
            for one_batch in dataset:
                per_replica_loss = self.strategy.experimental_run_v2(self.train_step, args=(one_batch, ))
                batch_loss = self.strategy.reduce(tf.distribute.ReduceOp.SUM, per_replica_loss, axis=None)
                total_loss += batch_loss
                num_train_batches += 1
                if num_train_batches % 100 == 0:
                    tf.print('Trained batch', num_train_batches, 'batch loss', batch_loss, 'epoch total loss', total_loss / num_train_batches)
            return total_loss, num_train_batches

        @tf.function
        def distributed_val_epoch(dataset):
            total_loss = 0.0
            num_val_batches = 0.0
            for one_batch in dataset:
                per_replica_loss = self.strategy.experimental_run_v2(self.val_step, args=(one_batch, ))
                num_val_batches += 1
                batch_loss = self.strategy.reduce(tf.distribute.ReduceOp.SUM, per_replica_loss, axis=None)
                if num_val_batches % 100 == 0:
                    tf.print('Validated batch', num_val_batches, 'batch loss', batch_loss)
                if not tf.math.is_nan(batch_loss):
                    total_loss += batch_loss
                else:
                    num_val_batches -= 1

            return total_loss, num_val_batches

        for epoch in range(1, self.epochs + 1):
            tf.summary.experimental.set_step(epoch)

            self.lr_decay()
            tf.summary.scalar('epoch learning rate',self.current_learning_rate)

            print('Start epoch {} with learning rate {}'.format(epoch, self.current_learning_rate))

            train_total_loss, num_train_batches = distributed_train_epoch(train_dist_dataset)
            train_loss = train_total_loss / num_train_batches
            print('Epoch {} train loss {}'.format(epoch, train_loss))
            self.history['loss'].append(train_loss)
            tf.summary.scalar('epoch train loss', train_loss)

            val_total_loss, num_val_batches = distributed_val_epoch(val_dist_dataset)
            val_loss = val_total_loss / num_val_batches
            print('Epoch {} val loss {}'.format(epoch, val_loss))
            self.history['val_loss'].append(val_loss)
            tf.summary.scalar('epoch val loss', val_loss)

            if val_loss < self.lowest_val_loss:
                self.save_model(epoch, val_loss)
                self.lowest_val_loss = val_loss
            self.last_val_loss = val_loss

        return self.best_model

    def save_model(self, epoch, loss):
        model_name = './models/model-epoch-{}-loss-{:.4f}.h5'.format(epoch, loss)
        self.model.save_weights(model_name)
        self.best_model = model_name
        print("Model {} saved.".format(model_name))


def create_dataset(tfrecords, batch_size, num_heatmap, is_train):
    preprocess = Preprocessor(IMAGE_SHAPE, (HEATMAP_SHAPE[0], HEATMAP_SHAPE[1], num_heatmap), is_train)

    dataset = tf.data.Dataset.list_files(tfrecords)
    dataset = tf.data.TFRecordDataset(dataset)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    if is_train:
        dataset = dataset.shuffle(batch_size)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
def hg_train(history, epochs, learning_rate, num_heatmap, batch_size, train_tfrecords, val_tfrecords):
    strategy = tf.distribute.MirroredStrategy()
    global_batch_size = strategy.num_replicas_in_sync * batch_size
    train_dataset = create_dataset(train_tfrecords, global_batch_size, num_heatmap, is_train=True)
    val_dataset = create_dataset(val_tfrecords, global_batch_size, num_heatmap, is_train=False)

    if not os.path.exists(os.path.join('./models')):
        os.makedirs(os.path.join('./models/'))

    with strategy.scope():
        train_dist_dataset = strategy.experimental_distribute_dataset(train_dataset)
        val_dist_dataset = strategy.experimental_distribute_dataset(val_dataset)

        model = StackedHourglassNetwork(IMAGE_SHAPE, 4, 1, num_heatmap)
        model.summary()

        trainer = HGTrainer(
            model,
            history,
            epochs,
            global_batch_size,
            strategy,
            initial_learning_rate=learning_rate)

        print('Start training...')
        trainer.run(train_dist_dataset, val_dist_dataset)
        return model

# %% [markdown]
# ## SimpleBaseline

# %%
class SBTrainer(object):
    def __init__(self,
                 model,
                 history,
                 epochs,
                 global_batch_size,
                 strategy,
                 initial_learning_rate):
        self.model = model
        self.history = history
        self.epochs = epochs
        self.strategy = strategy
        self.global_batch_size = global_batch_size
        self.loss_object = tf.keras.losses.MeanSquaredError(reduction=tf.keras.losses.Reduction.NONE)
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)

        self.current_learning_rate = initial_learning_rate
        self.last_val_loss = math.inf
        self.lowest_val_loss = math.inf
        self.patience_count = 0
        self.max_patience = 10
        self.best_model = None

    def lr_decay(self):
        if self.patience_count >= self.max_patience:
            self.current_learning_rate /= 10.0
            self.patience_count = 0
        elif self.last_val_loss == self.lowest_val_loss:
            self.patience_count = 0
        self.patience_count += 1
        self.optimizer.learning_rate = self.current_learning_rate

    def lr_decay_step(self, epoch):
        if epoch == 25 or epoch == 50 or epoch == 75:
            self.current_learning_rate /= 10.0
        self.optimizer.learning_rate = self.current_learning_rate

    def compute_loss(self, labels, outputs):
        if type(outputs)!=list:
            outputs = [outputs]
        loss = 0
        for output in outputs:
            weights = tf.cast(labels > 0, dtype=tf.float32) * 81 + 1
            loss += tf.math.reduce_mean(tf.math.square(labels - output) * weights) * (1. / self.global_batch_size)
        return loss

    def train_step(self, inputs):
        images, labels = inputs
        with tf.GradientTape() as tape:
            outputs = self.model(images, training=True)
            loss = self.compute_loss(labels, outputs)

        grads = tape.gradient(target=loss, sources=self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

        return loss

    def val_step(self, inputs):
        images, labels = inputs
        outputs = self.model(images, training=False)
        loss = self.compute_loss(labels, outputs)
        return loss

    def run(self, train_dist_dataset, val_dist_dataset):
        @tf.function
        def distributed_train_epoch(dataset):
            tf.print('Start distributed traininng...')
            total_loss = 0.0
            num_train_batches = 0.0
            for one_batch in dataset:
                per_replica_loss = self.strategy.experimental_run_v2(self.train_step, args=(one_batch, ))
                batch_loss = self.strategy.reduce(tf.distribute.ReduceOp.SUM, per_replica_loss, axis=None)
                total_loss += batch_loss
                num_train_batches += 1
                if num_train_batches % 100 == 0:
                    tf.print('Trained batch', num_train_batches, 'batch loss', batch_loss, 'epoch total loss', total_loss / num_train_batches)
            return total_loss, num_train_batches

        @tf.function
        def distributed_val_epoch(dataset):
            total_loss = 0.0
            num_val_batches = 0.0
            for one_batch in dataset:
                per_replica_loss = self.strategy.experimental_run_v2(self.val_step, args=(one_batch, ))
                num_val_batches += 1
                batch_loss = self.strategy.reduce(tf.distribute.ReduceOp.SUM, per_replica_loss, axis=None)
                if num_val_batches % 100 == 0:
                    tf.print('Validated batch', num_val_batches, 'batch loss', batch_loss)
                if not tf.math.is_nan(batch_loss):
                    total_loss += batch_loss
                else:
                    num_val_batches -= 1

            return total_loss, num_val_batches

        for epoch in range(1, self.epochs + 1):
            tf.summary.experimental.set_step(epoch)

            self.lr_decay()
            tf.summary.scalar('epoch learning rate',self.current_learning_rate)

            print('Start epoch {} with learning rate {}'.format(epoch, self.current_learning_rate))

            train_total_loss, num_train_batches = distributed_train_epoch(train_dist_dataset)
            train_loss = train_total_loss / num_train_batches
            print('Epoch {} train loss {}'.format(epoch, train_loss))
            self.history['loss'].append(train_loss)
            tf.summary.scalar('epoch train loss', train_loss)

            val_total_loss, num_val_batches = distributed_val_epoch(val_dist_dataset)
            val_loss = val_total_loss / num_val_batches
            print('Epoch {} val loss {}'.format(epoch, val_loss))
            self.history['val_loss'].append(val_loss)
            tf.summary.scalar('epoch val loss', val_loss)

            if val_loss < self.lowest_val_loss:
                self.save_model(epoch, val_loss)
                self.lowest_val_loss = val_loss
            self.last_val_loss = val_loss

        return self.best_model

    def save_model(self, epoch, loss):
        model_name = './models/model-epoch-{}-loss-{:.4f}.h5'.format(epoch, loss)
        self.model.save_weights(model_name)
        self.best_model = model_name
        print("Model {} saved.".format(model_name))


def create_dataset(tfrecords, batch_size, num_heatmap, is_train):
    preprocess = Preprocessor(IMAGE_SHAPE, (HEATMAP_SHAPE[0], HEATMAP_SHAPE[1], num_heatmap), is_train)

    dataset = tf.data.Dataset.list_files(tfrecords)
    dataset = tf.data.TFRecordDataset(dataset)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    if is_train:
        dataset = dataset.shuffle(batch_size)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
def sb_train(history, epochs, learning_rate, num_heatmap, batch_size, train_tfrecords, val_tfrecords):
    strategy = tf.distribute.MirroredStrategy()
    global_batch_size = strategy.num_replicas_in_sync * batch_size
    train_dataset = create_dataset(train_tfrecords, global_batch_size, num_heatmap, is_train=True)
    val_dataset = create_dataset(val_tfrecords, global_batch_size, num_heatmap, is_train=False)

    if not os.path.exists(os.path.join('./models')):
        os.makedirs(os.path.join('./models/'))

    with strategy.scope():
        train_dist_dataset = strategy.experimental_distribute_dataset(train_dataset)
        val_dist_dataset = strategy.experimental_distribute_dataset(val_dataset)

        model = Simplebaseline()
        model.summary()

        trainer = SBTrainer(
            model,
            history,
            epochs,
            global_batch_size,
            strategy,
            initial_learning_rate=learning_rate)

        print('Start training...')
        trainer.run(train_dist_dataset, val_dist_dataset)
        return model

# %% [markdown]
# # 모델 시험

# %%
TEST_IMAGE = os.path.join(PROJECT_PATH, 'test_image.jpg')

R_ANKLE = 0
R_KNEE = 1
R_HIP = 2
L_HIP = 3
L_KNEE = 4
L_ANKLE = 5
PELVIS = 6
THORAX = 7
UPPER_NECK = 8
HEAD_TOP = 9
R_WRIST = 10
R_ELBOW = 11
R_SHOULDER = 12
L_SHOULDER = 13
L_ELBOW = 14
L_WRIST = 15

MPII_BONES = [
    [R_ANKLE, R_KNEE],
    [R_KNEE, R_HIP],
    [R_HIP, PELVIS],
    [L_HIP, PELVIS],
    [L_HIP, L_KNEE],
    [L_KNEE, L_ANKLE],
    [PELVIS, THORAX],
    [THORAX, UPPER_NECK],
    [UPPER_NECK, HEAD_TOP],
    [R_WRIST, R_ELBOW],
    [R_ELBOW, R_SHOULDER],
    [THORAX, R_SHOULDER],

    [THORAX, L_SHOULDER],
    [L_SHOULDER, L_ELBOW],
    [L_ELBOW, L_WRIST]
]

def find_max_coordinates(heatmaps):
    flatten_heatmaps = tf.reshape(heatmaps, (4096, 16))
    indices = tf.math.argmax(flatten_heatmaps, axis=0)
    y = tf.cast(indices / 64, dtype=tf.int64)
    x = indices - 64 * y
    return tf.stack([x, y], axis=1).numpy()


def extract_keypoints_from_heatmap(heatmaps):
    max_keypoints = find_max_coordinates(heatmaps)

    padded_heatmap = np.pad(heatmaps, [[1,1],[1,1],[0,0]], mode='constant')
    adjusted_keypoints = []
    for i, keypoint in enumerate(max_keypoints):
        max_y = keypoint[1]+1
        max_x = keypoint[0]+1
        
        patch = padded_heatmap[max_y-1:max_y+2, max_x-1:max_x+2, i]
        patch[1][1] = 0
        
        index = np.argmax(patch)
        
        next_y = index // 3
        next_x = index - next_y * 3
        delta_y = (next_y - 1) / 4
        delta_x = (next_x - 1) / 4
        
        adjusted_keypoint_x = keypoint[0] + delta_x
        adjusted_keypoint_y = keypoint[1] + delta_y
        adjusted_keypoints.append((adjusted_keypoint_x, adjusted_keypoint_y))
        
    adjusted_keypoints = np.clip(adjusted_keypoints, 0, 64)
    normalized_keypoints = adjusted_keypoints / 64
    return normalized_keypoints


def predict(model, image_path):
    encoded = tf.io.read_file(image_path)
    image = tf.io.decode_jpeg(encoded)
    inputs = tf.image.resize(image, (256, 256))
    inputs = tf.cast(inputs, tf.float32) / 127.5 - 1
    inputs = tf.expand_dims(inputs, 0)
    outputs = model(inputs, training=False)
    if type(outputs) != list:
        outputs = [outputs]
    heatmap = tf.squeeze(outputs[-1], axis=0).numpy()
    kp = extract_keypoints_from_heatmap(heatmap)
    return image, kp

# %% [markdown]
# # 시각화

# %%
def draw_keypoints_on_image(image, keypoints, index=None):
    fig,ax = plt.subplots(1)
    ax.imshow(image)
    joints = []
    for i, joint in enumerate(keypoints):
        joint_x = joint[0] * image.shape[1]
        joint_y = joint[1] * image.shape[0]
        if index is not None and index != i:
            continue
        plt.scatter(joint_x, joint_y, s=10, c='red', marker='o')
    plt.show()


def draw_skeleton_on_image(image, keypoints, index=None):
    fig,ax = plt.subplots(1)
    ax.imshow(image)
    joints = []
    for i, joint in enumerate(keypoints):
        joint_x = joint[0] * image.shape[1]
        joint_y = joint[1] * image.shape[0]
        joints.append((joint_x, joint_y))
    
    for bone in MPII_BONES:
        joint_1 = joints[bone[0]]
        joint_2 = joints[bone[1]]
        plt.plot([joint_1[0], joint_2[0]], [joint_1[1], joint_2[1]], linewidth=5, alpha=0.7)
    plt.show()

# %%
def draw_history(hg_history, sb_history):
    plt.title('loss')
    plt.plot(hg_history['loss'], label='hour glass')
    plt.plot(sb_history['loss'], label='simple baseline')
    plt.legend(loc='lower right')
    plt.show()
    
    plt.title('val loss')
    plt.plot(hg_history['val_loss'], label='hour glass')
    plt.plot(sb_history['val_loss'], label='simple baseline')
    plt.legend(loc='lower right')
    plt.show()

# %% [markdown]
# # 메인

# %% [markdown]
# ## TFRecord 생성

# %% [markdown]
# ray.init()
# make_trrecord()

# %% [markdown]
# ## 모델 생성 & 훈련

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

train_tfrecords = os.path.join(TFRECORD_PATH, 'train*')
val_tfrecords = os.path.join(TFRECORD_PATH, 'val*')
epochs = 10
batch_size = 8
num_heatmap = 16
learning_rate = 0.0007

automatic_gpu_usage()
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
hg_history_map = {'loss': [], 'val_loss': []}
hg_model = hg_train(hg_history_map, epochs, learning_rate, num_heatmap, batch_size, train_tfrecords, val_tfrecords)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "stacked_hourglass"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 128, 128, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         re_lu[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 64) 4160        re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 128, 128, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 36928       re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 128, 128, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 128 8320        re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 8320        re_lu_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 128 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 64, 64, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   8256        re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   36928       re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 128)  8320        re_lu_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 128)  0           max_pooling2d[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 128)  512         add_1[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 64, 64, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 128)  16512       re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 64, 64, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 128)  147584      re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 64, 64, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  33024       add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  33024       re_lu_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 256)  1024        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 32, 32, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 128)  32896       re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 32, 32, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 128)  147584      re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 32, 32, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 256)  33024       re_lu_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 256)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 256)  1024        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 16, 16, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  32896       re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 16, 16, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 128)  147584      re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 16, 16, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 256)  33024       re_lu_27[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 256)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 256)    1024        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 8, 8, 256)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 128)    32896       re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 128)    512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 128)    147584      re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 128)    512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 256)    33024       re_lu_36[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 256)    0           max_pooling2d_3[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 256)    1024        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 4, 4, 256)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 128)    32896       re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 128)    512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 4, 4, 128)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 128)    147584      re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 4, 4, 128)    512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 4, 4, 128)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 256)    33024       re_lu_45[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 256)    0           max_pooling2d_4[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 256)    1024        add_14[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 4, 4, 256)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 256)    1024        add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 128)    32896       re_lu_46[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 8, 8, 256)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 128)    512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 128)    32896       re_lu_37[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 4, 4, 128)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 128)    512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 128)    147584      re_lu_47[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 128)    512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 128)    147584      re_lu_38[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 4, 4, 128)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 128)    512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 256)    33024       re_lu_48[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 256)    0           add_14[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 256)    33024       re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 4, 4, 256)    1024        add_15[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 256)    0           add_11[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 4, 4, 256)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 256)    1024        add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 128)    32896       re_lu_49[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 8, 8, 256)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 4, 4, 128)    512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 128)    32896       re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 256)  1024        add_8[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 4, 4, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 128)    512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 16, 16, 256)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 128)    147584      re_lu_50[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  32896       re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 4, 4, 128)    512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 128)    147584      re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 4, 4, 128)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 128)    512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 16, 16, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 256)    33024       re_lu_51[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 128)  147584      re_lu_29[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, 4, 256)    0           add_15[0][0]
#                                                                  conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 256)    33024       re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 128)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 8, 8, 256)    0           add_16[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 256)    0           add_12[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 16, 16, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 8, 8, 256)]  0           up_sampling2d[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 256)  33024       re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 256)    1024        tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 256)  0           add_8[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 8, 8, 256)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 256)  1024        add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 128)    32896       re_lu_52[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 16, 16, 256)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 128)    512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 128)  32896       re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 256)  1024        add_5[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 32, 32, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 128)    147584      re_lu_53[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 16, 16, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 128)  32896       re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 128)    512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 128)  147584      re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 128)  512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 32, 32, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 256)    33024       re_lu_54[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 16, 16, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 128)  147584      re_lu_20[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           tf_op_layer_AddV2[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 256)  33024       re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 256)  0           add_9[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 32, 32, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 16, 16, 256) 0           up_sampling2d_1[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 256)  33024       re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 16, 16, 256)  1024        tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 256)  0           add_5[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 16, 16, 256)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 256)  1024        add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 16, 128)  32896       re_lu_55[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 32, 32, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 16, 16, 128)  512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 128)  32896       re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 256)  1024        add_2[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 16, 16, 128)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 64, 64, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 16, 16, 128)  147584      re_lu_56[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 32, 32, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  32896       re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 16, 16, 128)  512         conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 128)  147584      re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 16, 16, 128)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 64, 64, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 16, 16, 256)  33024       re_lu_57[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 32, 32, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      re_lu_11[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 16, 16, 256)  0           tf_op_layer_AddV2_1[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 256)  33024       re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0           add_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 256)  0           add_6[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 64, 64, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 32, 32, 256) 0           up_sampling2d_2[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  33024       re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 256)  1024        tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 256)  0           add_2[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_58 (ReLU)                 (None, 32, 32, 256)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 256)  1024        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 128)  32896       re_lu_58[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 64, 64, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 128)  512         conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 128)  32896       re_lu_13[0][0]
# __________________________________________________________________________________________________
# re_lu_59 (ReLU)                 (None, 32, 32, 128)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 128)  147584      re_lu_59[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 64, 64, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 128)  512         conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 128)  147584      re_lu_14[0][0]
# __________________________________________________________________________________________________
# re_lu_60 (ReLU)                 (None, 32, 32, 128)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 256)  33024       re_lu_60[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 64, 64, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 256)  0           tf_op_layer_AddV2_2[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 256)  33024       re_lu_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 256)  0           add_19[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 256)  0           add_3[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 64, 64, 256) 0           up_sampling2d_3[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 64, 64, 256)  1024        tf_op_layer_AddV2_3[0][0]
# __________________________________________________________________________________________________
# re_lu_61 (ReLU)                 (None, 64, 64, 256)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# ...
# Epoch 5 val loss 2.2373077869415283
# Model ./models/model-epoch-5-loss-2.2373.h5 saved.
# Start epoch 6 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 2.39174271 epoch total loss 2.29134893
# Trained batch 200 batch loss 2.04918885 epoch total loss 2.23670888
# Trained batch 300 batch loss 1.75357985 epoch total loss 2.24178171
# Trained batch 400 batch loss 2.09440327 epoch total loss 2.23963642
# Trained batch 500 batch loss 2.18805027 epoch total loss 2.22494316
# Trained batch 600 batch loss 2.60245514 epoch total loss 2.22179985
# Trained batch 700 batch loss 2.77568412 epoch total loss 2.21599507
# Trained batch 800 batch loss 2.05263495 epoch total loss 2.20819235
# Trained batch 900 batch loss 1.90468907 epoch total loss 2.21005797
# Trained batch 1000 batch loss 2.52903605 epoch total loss 2.21920085
# Trained batch 1100 batch loss 2.25753117 epoch total loss 2.22697616
# Trained batch 1200 batch loss 2.57520866 epoch total loss 2.22680545
# Trained batch 1300 batch loss 2.31602573 epoch total loss 2.22821951
# Trained batch 1400 batch loss 2.53079462 epoch total loss 2.22627
# Trained batch 1500 batch loss 2.37046432 epoch total loss 2.22671986
# Trained batch 1600 batch loss 2.33364391 epoch total loss 2.22870493
# Trained batch 1700 batch loss 2.32431 epoch total loss 2.2308619
# Trained batch 1800 batch loss 2.23198676 epoch total loss 2.22581601
# Trained batch 1900 batch loss 1.96080756 epoch total loss 2.22812176
# Trained batch 2000 batch loss 1.91504097 epoch total loss 2.23023
# Trained batch 2100 batch loss 1.83172035 epoch total loss 2.23193669
# Trained batch 2200 batch loss 2.22066045 epoch total loss 2.23206949
# Trained batch 2300 batch loss 2.476228 epoch total loss 2.23510051
# Trained batch 2400 batch loss 2.20297527 epoch total loss 2.23591924
# Trained batch 2500 batch loss 2.16444016 epoch total loss 2.23410201
# Trained batch 2600 batch loss 1.99064445 epoch total loss 2.23487973
# Trained batch 2700 batch loss 3.11348629 epoch total loss 2.23180103
# Epoch 6 train loss 2.230125904083252
# Validated batch 100 batch loss 2.53467655
# Validated batch 200 batch loss 2.3315649
# Validated batch 300 batch loss 2.61178446
# Validated batch 400 batch loss 2.23092699
# Validated batch 500 batch loss 2.29757547
# Validated batch 600 batch loss 2.66099691
# Validated batch 700 batch loss 2.07636309
# Validated batch 800 batch loss 2.25436234
# Validated batch 900 batch loss 1.39768088
# Validated batch 1000 batch loss 2.06225967
# Validated batch 1100 batch loss 2.1479032
# Validated batch 1200 batch loss 2.22280574
# Validated batch 1300 batch loss 2.21039057
# Validated batch 1400 batch loss 2.38902
# Validated batch 1500 batch loss 1.88134277
# Validated batch 1600 batch loss 2.42108631
# Validated batch 1700 batch loss 2.37031484
# Validated batch 1800 batch loss 2.40274262
# Validated batch 1900 batch loss 1.87144303
# Validated batch 2000 batch loss 1.43533683
# Validated batch 2100 batch loss 2.11442757
# Validated batch 2200 batch loss 2.64727306
# Validated batch 2300 batch loss 1.90229774
# Validated batch 2400 batch loss 2.007833
# Validated batch 2500 batch loss 1.85562754
# Validated batch 2600 batch loss 2.09625864
# Validated batch 2700 batch loss 2.39350247
# Epoch 6 val loss 2.2049012184143066
# Model ./models/model-epoch-6-loss-2.2049.h5 saved.
# Start epoch 7 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 2.1758461 epoch total loss 2.14976263
# Trained batch 200 batch loss 2.0712049 epoch total loss 2.16196966
# Trained batch 300 batch loss 2.35158229 epoch total loss 2.17595744
# Trained batch 400 batch loss 2.22649074 epoch total loss 2.15422201
# Trained batch 500 batch loss 1.9412415 epoch total loss 2.18781924
# Trained batch 600 batch loss 1.93084013 epoch total loss 2.18973064
# Trained batch 700 batch loss 2.6515286 epoch total loss 2.18067026
# Trained batch 800 batch loss 2.05802631 epoch total loss 2.19133735
# Trained batch 900 batch loss 2.44982958 epoch total loss 2.18723559
# Trained batch 1000 batch loss 2.39188576 epoch total loss 2.18708467
# Trained batch 1100 batch loss 1.62409854 epoch total loss 2.17854166
# Trained batch 1200 batch loss 1.97600234 epoch total loss 2.18401742
# Trained batch 1300 batch loss 1.96388268 epoch total loss 2.18302846
# Trained batch 1400 batch loss 2.09219217 epoch total loss 2.18480706
# Trained batch 1500 batch loss 2.43646097 epoch total loss 2.19260359
# Trained batch 1600 batch loss 2.08565235 epoch total loss 2.19173241
# Trained batch 1700 batch loss 2.28037572 epoch total loss 2.19477606
# Trained batch 1800 batch loss 1.90066481 epoch total loss 2.19725084
# Trained batch 1900 batch loss 2.01775241 epoch total loss 2.19141483
# Trained batch 2000 batch loss 1.96705484 epoch total loss 2.19315553
# Trained batch 2100 batch loss 1.94565725 epoch total loss 2.18714
# Trained batch 2200 batch loss 2.13504124 epoch total loss 2.18522096
# Trained batch 2300 batch loss 2.02253413 epoch total loss 2.18412304
# Trained batch 2400 batch loss 2.02251029 epoch total loss 2.18441319
# Trained batch 2500 batch loss 2.23986053 epoch total loss 2.18716216
# Trained batch 2600 batch loss 2.14883 epoch total loss 2.18569851
# Trained batch 2700 batch loss 2.3071363 epoch total loss 2.18538785
# Epoch 7 train loss 2.185832977294922
# Validated batch 100 batch loss 1.92391562
# Validated batch 200 batch loss 2.38152409
# Validated batch 300 batch loss 2.26789713
# Validated batch 400 batch loss 1.84595442
# Validated batch 500 batch loss 2.22780609
# Validated batch 600 batch loss 2.13203716
# Validated batch 700 batch loss 2.20524836
# Validated batch 800 batch loss 2.31416655
# Validated batch 900 batch loss 2.72578716
# Validated batch 1000 batch loss 2.24228859
# Validated batch 1100 batch loss 2.29099894
# Validated batch 1200 batch loss 1.8697902
# Validated batch 1300 batch loss 2.34159279
# Validated batch 1400 batch loss 2.28689861
# Validated batch 1500 batch loss 2.35126543
# Validated batch 1600 batch loss 2.45801497
# Validated batch 1700 batch loss 2.22481656
# Validated batch 1800 batch loss 2.35256314
# Validated batch 1900 batch loss 2.35810471
# Validated batch 2000 batch loss 2.29541135
# Validated batch 2100 batch loss 1.91812396
# Validated batch 2200 batch loss 2.55861545
# Validated batch 2300 batch loss 2.11664
# Validated batch 2400 batch loss 2.18241549
# Validated batch 2500 batch loss 2.15415478
# Validated batch 2600 batch loss 2.25849581
# Validated batch 2700 batch loss 2.28892446
# Epoch 7 val loss 2.1540234088897705
# Model ./models/model-epoch-7-loss-2.1540.h5 saved.
# Start epoch 8 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 2.12991571 epoch total loss 2.10439658
# Trained batch 200 batch loss 1.947855 epoch total loss 2.07326937
# Trained batch 300 batch loss 2.34193563 epoch total loss 2.10733271
# Trained batch 400 batch loss 2.57616949 epoch total loss 2.09835029
# Trained batch 500 batch loss 2.22642207 epoch total loss 2.10121799
# Trained batch 600 batch loss 2.1643343 epoch total loss 2.10145545
# Trained batch 700 batch loss 2.55057788 epoch total loss 2.11062407
# Trained batch 800 batch loss 2.50311327 epoch total loss 2.10648
# Trained batch 900 batch loss 2.24217772 epoch total loss 2.12072396
# Trained batch 1000 batch loss 1.83167779 epoch total loss 2.12812734
# Trained batch 1100 batch loss 2.54032326 epoch total loss 2.1302619
# Trained batch 1200 batch loss 2.59823918 epoch total loss 2.135391
# Trained batch 1300 batch loss 2.05114126 epoch total loss 2.1353476
# Trained batch 1400 batch loss 2.27061105 epoch total loss 2.13241959
# Trained batch 1500 batch loss 2.35993338 epoch total loss 2.13696408
# Trained batch 1600 batch loss 2.27633858 epoch total loss 2.13780379
# Trained batch 1700 batch loss 1.66589189 epoch total loss 2.13777161
# Trained batch 1800 batch loss 1.81501937 epoch total loss 2.1341753
# Trained batch 1900 batch loss 2.4257946 epoch total loss 2.13397908
# Trained batch 2000 batch loss 2.08272409 epoch total loss 2.13712883
# Trained batch 2100 batch loss 1.79747796 epoch total loss 2.1375773
# Trained batch 2200 batch loss 2.18393826 epoch total loss 2.13933897
# Trained batch 2300 batch loss 2.67335868 epoch total loss 2.14104915
# Trained batch 2400 batch loss 2.3242619 epoch total loss 2.14206457
# Trained batch 2500 batch loss 2.03019524 epoch total loss 2.14145637
# Trained batch 2600 batch loss 2.23768 epoch total loss 2.14105153
# Trained batch 2700 batch loss 1.79215598 epoch total loss 2.14267397
# Epoch 8 train loss 2.1453051567077637
# Validated batch 100 batch loss 1.73620665
# Validated batch 200 batch loss 2.1752665
# Validated batch 300 batch loss 1.78832221
# Validated batch 400 batch loss 2.14928722
# Validated batch 500 batch loss 2.1665659
# Validated batch 600 batch loss 2.27114
# Validated batch 700 batch loss 2.34928513
# Validated batch 800 batch loss 2.34026432
# Validated batch 900 batch loss 2.10671806
# Validated batch 1000 batch loss 2.08234477
# Validated batch 1100 batch loss 2.26563382
# Validated batch 1200 batch loss 2.04452562
# Validated batch 1300 batch loss 2.38041925
# Validated batch 1400 batch loss 2.25516415
# Validated batch 1500 batch loss 2.28460121
# Validated batch 1600 batch loss 2.25211787
# Validated batch 1700 batch loss 2.43516111
# Validated batch 1800 batch loss 2.43301582
# Validated batch 1900 batch loss 1.99040949
# Validated batch 2000 batch loss 1.93499887
# Validated batch 2100 batch loss 2.23270702
# Validated batch 2200 batch loss 1.85964525
# Validated batch 2300 batch loss 2.61941886
# Validated batch 2400 batch loss 1.89011192
# Validated batch 2500 batch loss 2.5728159
# Validated batch 2600 batch loss 2.43325448
# Validated batch 2700 batch loss 2.34154415
# Epoch 8 val loss 2.1401479244232178
# Model ./models/model-epoch-8-loss-2.1401.h5 saved.
# Start epoch 9 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 1.77530551 epoch total loss 2.1006825
# Trained batch 200 batch loss 2.13909745 epoch total loss 2.09734082
# Trained batch 300 batch loss 2.35910463 epoch total loss 2.07958651
# Trained batch 400 batch loss 1.96325898 epoch total loss 2.06318784
# Trained batch 500 batch loss 2.349648 epoch total loss 2.083565
# Trained batch 600 batch loss 2.43619061 epoch total loss 2.08471918
# Trained batch 700 batch loss 2.4528718 epoch total loss 2.08627272
# Trained batch 800 batch loss 1.7473557 epoch total loss 2.07978749
# Trained batch 900 batch loss 2.23003 epoch total loss 2.09858775
# Trained batch 1000 batch loss 2.15208578 epoch total loss 2.09893656
# Trained batch 1100 batch loss 2.15501428 epoch total loss 2.10195804
# Trained batch 1200 batch loss 2.15740776 epoch total loss 2.09977913
# Trained batch 1300 batch loss 2.06930423 epoch total loss 2.10172868
# Trained batch 1400 batch loss 2.15082693 epoch total loss 2.1114862
# Trained batch 1500 batch loss 2.07646799 epoch total loss 2.11220193
# Trained batch 1600 batch loss 2.33879542 epoch total loss 2.10653877
# Trained batch 1700 batch loss 2.25786352 epoch total loss 2.10415173
# Trained batch 1800 batch loss 1.92332864 epoch total loss 2.09858
# Trained batch 1900 batch loss 2.12220049 epoch total loss 2.10584641
# Trained batch 2000 batch loss 2.12829971 epoch total loss 2.10546708
# Trained batch 2100 batch loss 2.05696416 epoch total loss 2.10796452
# Trained batch 2200 batch loss 2.2843926 epoch total loss 2.10665917
# Trained batch 2300 batch loss 1.86270308 epoch total loss 2.11110473
# Trained batch 2400 batch loss 2.42501831 epoch total loss 2.1113987
# Trained batch 2500 batch loss 1.68496859 epoch total loss 2.11067843
# Trained batch 2600 batch loss 2.68185067 epoch total loss 2.11313081
# Trained batch 2700 batch loss 2.30713487 epoch total loss 2.11303639
# Epoch 9 train loss 2.113086462020874
# Validated batch 100 batch loss 2.41264
# Validated batch 200 batch loss 2.11839938
# Validated batch 300 batch loss 2.09558439
# Validated batch 400 batch loss 1.42227
# Validated batch 500 batch loss 2.17131925
# Validated batch 600 batch loss 2.07409358
# Validated batch 700 batch loss 2.3389225
# Validated batch 800 batch loss 2.53201795
# Validated batch 900 batch loss 1.67061865
# Validated batch 1000 batch loss 2.23941326
# Validated batch 1100 batch loss 1.84677672
# Validated batch 1200 batch loss 2.20151758
# Validated batch 1300 batch loss 1.82268286
# Validated batch 1400 batch loss 2.00126958
# Validated batch 1500 batch loss 2.29597211
# Validated batch 1600 batch loss 1.98351598
# Validated batch 1700 batch loss 2.45340776
# Validated batch 1800 batch loss 2.40342808
# Validated batch 1900 batch loss 2.17959881
# Validated batch 2000 batch loss 2.79137135
# Validated batch 2100 batch loss 2.00215769
# Validated batch 2200 batch loss 2.62329197
# Validated batch 2300 batch loss 1.84111512
# Validated batch 2400 batch loss 1.92422032
# Validated batch 2500 batch loss 1.84513485
# Validated batch 2600 batch loss 2.07664943
# Validated batch 2700 batch loss 2.25359058
# Epoch 9 val loss 2.081003427505493
# Model ./models/model-epoch-9-loss-2.0810.h5 saved.
# Start epoch 10 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 1.84744906 epoch total loss 2.02097082
# Trained batch 200 batch loss 1.96278524 epoch total loss 2.0648632
# Trained batch 300 batch loss 2.24778676 epoch total loss 2.05868173
# Trained batch 400 batch loss 2.5742178 epoch total loss 2.05584717
# Trained batch 500 batch loss 1.72874653 epoch total loss 2.05633712
# Trained batch 600 batch loss 2.29825926 epoch total loss 2.06739
# Trained batch 700 batch loss 2.60572577 epoch total loss 2.0748229
# Trained batch 800 batch loss 1.6118176 epoch total loss 2.07044983
# Trained batch 900 batch loss 2.08243251 epoch total loss 2.07633734
# Trained batch 1000 batch loss 2.01107693 epoch total loss 2.08111882
# Trained batch 1100 batch loss 1.81639361 epoch total loss 2.07904267
# Trained batch 1200 batch loss 2.01578379 epoch total loss 2.07067466
# Trained batch 1300 batch loss 2.19055128 epoch total loss 2.08058119
# Trained batch 1400 batch loss 2.31868839 epoch total loss 2.07798767
# Trained batch 1500 batch loss 2.084 epoch total loss 2.077384
# Trained batch 1600 batch loss 1.69722915 epoch total loss 2.07561016
# Trained batch 1700 batch loss 2.09849405 epoch total loss 2.07608318
# Trained batch 1800 batch loss 1.90968 epoch total loss 2.07062697
# Trained batch 1900 batch loss 2.04756856 epoch total loss 2.0714817
# Trained batch 2000 batch loss 1.89867306 epoch total loss 2.07397246
# Trained batch 2100 batch loss 1.52953124 epoch total loss 2.07382393
# Trained batch 2200 batch loss 1.74541736 epoch total loss 2.07736444
# Trained batch 2300 batch loss 1.82590151 epoch total loss 2.0805316
# Trained batch 2400 batch loss 2.1034112 epoch total loss 2.07845592
# Trained batch 2500 batch loss 2.03249931 epoch total loss 2.07722163
# Trained batch 2600 batch loss 2.19867754 epoch total loss 2.08178377
# Trained batch 2700 batch loss 1.65271735 epoch total loss 2.08032036
# Epoch 10 train loss 2.079702138900757
# Validated batch 100 batch loss 2.3552115
# Validated batch 200 batch loss 2.06476
# Validated batch 300 batch loss 2.13204622
# Validated batch 400 batch loss 1.71338439
# Validated batch 500 batch loss 2.11116505
# Validated batch 600 batch loss 2.1367209
# Validated batch 700 batch loss 2.10568762
# Validated batch 800 batch loss 2.12707114
# Validated batch 900 batch loss 1.34694815
# Validated batch 1000 batch loss 1.8912915
# Validated batch 1100 batch loss 1.77890635
# Validated batch 1200 batch loss 2.21602631
# Validated batch 1300 batch loss 1.77547252
# Validated batch 1400 batch loss 2.2087543
# Validated batch 1500 batch loss 1.87503231
# Validated batch 1600 batch loss 2.23460603
# Validated batch 1700 batch loss 2.35992718
# Validated batch 1800 batch loss 1.69328
# Validated batch 1900 batch loss 2.08802319
# Validated batch 2000 batch loss 1.89878535
# Validated batch 2100 batch loss 1.84898829
# Validated batch 2200 batch loss 1.89995933
# Validated batch 2300 batch loss 2.21289825
# Validated batch 2400 batch loss 2.17639232
# Validated batch 2500 batch loss 2.403368
# Validated batch 2600 batch loss 2.1327033
# Validated batch 2700 batch loss 2.40520549
# Epoch 10 val loss 2.0732791423797607
# Model ./models/model-epoch-10-loss-2.0733.h5 saved.

# %%
sb_history_map = {'loss': [], 'val_loss': []}
sb_model = sb_train(sb_history_map, epochs, learning_rate, num_heatmap, batch_size, train_tfrecords, val_tfrecords)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Model: "simple_baseline"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, None, None, 2048)  23587712
# _________________________________________________________________
# sequential (Sequential)      (None, 64, 64, 256)       10489600
# _________________________________________________________________
# conv2d_244 (Conv2D)          (None, 64, 64, 16)        4112
# =================================================================
# Total params: 34,081,424
# Trainable params: 34,026,768
# Non-trainable params: 54,656
# _________________________________________________________________
# Start training...
# Start epoch 1 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.847035408 epoch total loss 0.849200904
# Trained batch 200 batch loss 0.684565067 epoch total loss 0.805060804
# Trained batch 300 batch loss 0.742749333 epoch total loss 0.781650066
# Trained batch 400 batch loss 0.715422928 epoch total loss 0.768984616
# Trained batch 500 batch loss 0.732177258 epoch total loss 0.761214137
# Trained batch 600 batch loss 0.6658445 epoch total loss 0.756386459
# Trained batch 700 batch loss 0.726115167 epoch total loss 0.747104764
# Trained batch 800 batch loss 0.678409696 epoch total loss 0.73946619
# Trained batch 900 batch loss 0.64502728 epoch total loss 0.733351171
# Trained batch 1000 batch loss 0.546643615 epoch total loss 0.728100538
# Trained batch 1100 batch loss 0.886778235 epoch total loss 0.722446799
# Trained batch 1200 batch loss 0.66207087 epoch total loss 0.717553735
# Trained batch 1300 batch loss 0.64723146 epoch total loss 0.71319288
# Trained batch 1400 batch loss 0.668302298 epoch total loss 0.709937394
# Trained batch 1500 batch loss 0.785585225 epoch total loss 0.707225502
# Trained batch 1600 batch loss 0.687634468 epoch total loss 0.704725623
# Trained batch 1700 batch loss 0.657225132 epoch total loss 0.702806056
# Trained batch 1800 batch loss 0.600010931 epoch total loss 0.700368524
# Trained batch 1900 batch loss 0.691545 epoch total loss 0.698873
# Trained batch 2000 batch loss 0.653172612 epoch total loss 0.698029041
# Trained batch 2100 batch loss 0.732946754 epoch total loss 0.696195424
# Trained batch 2200 batch loss 0.594234526 epoch total loss 0.69443804
# Trained batch 2300 batch loss 0.717655361 epoch total loss 0.692035854
# Trained batch 2400 batch loss 0.700897038 epoch total loss 0.690005481
# Trained batch 2500 batch loss 0.554378748 epoch total loss 0.68772465
# Trained batch 2600 batch loss 0.627985477 epoch total loss 0.686186492
# Trained batch 2700 batch loss 0.662958622 epoch total loss 0.683831751
# Epoch 1 train loss 0.6833101511001587
# Validated batch 100 batch loss 0.566430211
# Validated batch 200 batch loss 0.64015
# Validated batch 300 batch loss 0.582941473
# Validated batch 400 batch loss 0.662187159
# Validated batch 500 batch loss 0.568230331
# Validated batch 600 batch loss 0.6369344
# Validated batch 700 batch loss 0.734277368
# Validated batch 800 batch loss 0.789623857
# Validated batch 900 batch loss 0.675308108
# Validated batch 1000 batch loss 0.62651068
# Validated batch 1100 batch loss 0.642398298
# Validated batch 1200 batch loss 0.65434593
# Validated batch 1300 batch loss 0.647618234
# Validated batch 1400 batch loss 0.612658799
# Validated batch 1500 batch loss 0.743974149
# Validated batch 1600 batch loss 0.74771595
# Validated batch 1700 batch loss 0.686892748
# Validated batch 1800 batch loss 0.734699845
# Validated batch 1900 batch loss 0.560900509
# Validated batch 2000 batch loss 0.770242691
# Validated batch 2100 batch loss 0.664746284
# Validated batch 2200 batch loss 0.732682586
# Validated batch 2300 batch loss 0.568627119
# Validated batch 2400 batch loss 0.671636581
# Validated batch 2500 batch loss 0.607801259
# Validated batch 2600 batch loss 0.664341331
# Validated batch 2700 batch loss 0.653322339
# Epoch 1 val loss 0.6575781106948853
# Model ./models/model-epoch-1-loss-0.6576.h5 saved.
# Start epoch 2 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.66530329 epoch total loss 0.62520051
# Trained batch 200 batch loss 0.679700851 epoch total loss 0.630162716
# Trained batch 300 batch loss 0.517301738 epoch total loss 0.631797194
# Trained batch 400 batch loss 0.667633951 epoch total loss 0.631212
# Trained batch 500 batch loss 0.542458475 epoch total loss 0.630142
# Trained batch 600 batch loss 0.63782227 epoch total loss 0.624965489
# Trained batch 700 batch loss 0.609166086 epoch total loss 0.62463218
# Trained batch 800 batch loss 0.557363212 epoch total loss 0.622314632
# Trained batch 900 batch loss 0.595093966 epoch total loss 0.624521673
# Trained batch 1000 batch loss 0.671066105 epoch total loss 0.623102665
# Trained batch 1100 batch loss 0.636317492 epoch total loss 0.62182
# Trained batch 1200 batch loss 0.659761727 epoch total loss 0.621725261
# Trained batch 1300 batch loss 0.70805335 epoch total loss 0.621872425
# Trained batch 1400 batch loss 0.707065642 epoch total loss 0.623145223
# Trained batch 1500 batch loss 0.586126447 epoch total loss 0.623386681
# Trained batch 1600 batch loss 0.468166649 epoch total loss 0.62310046
# Trained batch 1700 batch loss 0.677379847 epoch total loss 0.623632431
# Trained batch 1800 batch loss 0.647539437 epoch total loss 0.62325573
# Trained batch 1900 batch loss 0.6669119 epoch total loss 0.62333703
# Trained batch 2000 batch loss 0.60784 epoch total loss 0.624216795
# Trained batch 2100 batch loss 0.625734806 epoch total loss 0.62425077
# Trained batch 2200 batch loss 0.60727942 epoch total loss 0.623514116
# Trained batch 2300 batch loss 0.70714128 epoch total loss 0.623537838
# Trained batch 2400 batch loss 0.74348855 epoch total loss 0.622586071
# Trained batch 2500 batch loss 0.61966759 epoch total loss 0.622022688
# Trained batch 2600 batch loss 0.609712958 epoch total loss 0.621352673
# Trained batch 2700 batch loss 0.575817227 epoch total loss 0.620478451
# Epoch 2 train loss 0.6203257441520691
# Validated batch 100 batch loss 0.52158016
# Validated batch 200 batch loss 0.640475154
# Validated batch 300 batch loss 0.61344862
# Validated batch 400 batch loss 0.557863832
# Validated batch 500 batch loss 0.481792241
# Validated batch 600 batch loss 0.583366036
# Validated batch 700 batch loss 0.565518439
# Validated batch 800 batch loss 0.654551685
# Validated batch 900 batch loss 0.553977609
# Validated batch 1000 batch loss 0.568540156
# Validated batch 1100 batch loss 0.623457134
# Validated batch 1200 batch loss 0.60989058
# Validated batch 1300 batch loss 0.6777004
# Validated batch 1400 batch loss 0.670752943
# Validated batch 1500 batch loss 0.683680534
# Validated batch 1600 batch loss 0.541089356
# Validated batch 1700 batch loss 0.543503702
# Validated batch 1800 batch loss 0.607222617
# Validated batch 1900 batch loss 0.666142344
# Validated batch 2000 batch loss 0.66066587
# Validated batch 2100 batch loss 0.603211939
# Validated batch 2200 batch loss 0.650324047
# Validated batch 2300 batch loss 0.530860901
# Validated batch 2400 batch loss 0.603440702
# Validated batch 2500 batch loss 0.490495354
# Validated batch 2600 batch loss 0.594505668
# Validated batch 2700 batch loss 0.676252246
# Epoch 2 val loss 0.6031081080436707
# Model ./models/model-epoch-2-loss-0.6031.h5 saved.
# Start epoch 3 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.852072 epoch total loss 0.588490903
# Trained batch 200 batch loss 0.552540898 epoch total loss 0.594959199
# Trained batch 300 batch loss 0.518186092 epoch total loss 0.596122861
# Trained batch 400 batch loss 0.658964336 epoch total loss 0.595377
# Trained batch 500 batch loss 0.676187098 epoch total loss 0.601776719
# Trained batch 600 batch loss 0.598582 epoch total loss 0.601784
# Trained batch 700 batch loss 0.60733068 epoch total loss 0.602193594
# Trained batch 800 batch loss 0.680452526 epoch total loss 0.603274584
# Trained batch 900 batch loss 0.459317207 epoch total loss 0.60391295
# Trained batch 1000 batch loss 0.618030608 epoch total loss 0.603054821
# Trained batch 1100 batch loss 0.505449 epoch total loss 0.603551
# Trained batch 1200 batch loss 0.571763694 epoch total loss 0.601683676
# Trained batch 1300 batch loss 0.465108067 epoch total loss 0.600787699
# Trained batch 1400 batch loss 0.60344553 epoch total loss 0.600118339
# Trained batch 1500 batch loss 0.621394098 epoch total loss 0.599231482
# Trained batch 1600 batch loss 0.622711658 epoch total loss 0.599283814
# Trained batch 1700 batch loss 0.598636627 epoch total loss 0.599390924
# Trained batch 1800 batch loss 0.601698399 epoch total loss 0.599171877
# Trained batch 1900 batch loss 0.606401265 epoch total loss 0.598664165
# Trained batch 2000 batch loss 0.628284514 epoch total loss 0.59738636
# Trained batch 2100 batch loss 0.604824483 epoch total loss 0.597218812
# Trained batch 2200 batch loss 0.496453792 epoch total loss 0.595993042
# Trained batch 2300 batch loss 0.6129601 epoch total loss 0.59474951
# Trained batch 2400 batch loss 0.488663077 epoch total loss 0.595105946
# Trained batch 2500 batch loss 0.626264811 epoch total loss 0.594790697
# Trained batch 2600 batch loss 0.747002602 epoch total loss 0.594761312
# Trained batch 2700 batch loss 0.593367517 epoch total loss 0.595171511
# Epoch 3 train loss 0.5949058532714844
# Validated batch 100 batch loss 0.628948212
# Validated batch 200 batch loss 0.601712823
# Validated batch 300 batch loss 0.657114506
# Validated batch 400 batch loss 0.540371299
# Validated batch 500 batch loss 0.444694132
# Validated batch 600 batch loss 0.558769464
# Validated batch 700 batch loss 0.548150361
# Validated batch 800 batch loss 0.614072204
# Validated batch 900 batch loss 0.382956564
# Validated batch 1000 batch loss 0.536188
# Validated batch 1100 batch loss 0.612340033
# Validated batch 1200 batch loss 0.580081642
# Validated batch 1300 batch loss 0.664135575
# Validated batch 1400 batch loss 0.610552311
# Validated batch 1500 batch loss 0.579533458
# Validated batch 1600 batch loss 0.691804111
# Validated batch 1700 batch loss 0.525256515
# Validated batch 1800 batch loss 0.527690411
# Validated batch 1900 batch loss 0.675134838
# Validated batch 2000 batch loss 0.411400378
# Validated batch 2100 batch loss 0.561888278
# Validated batch 2200 batch loss 0.626282573
# Validated batch 2300 batch loss 0.670770526
# Validated batch 2400 batch loss 0.632344127
# Validated batch 2500 batch loss 0.459801823
# Validated batch 2600 batch loss 0.524187
# Validated batch 2700 batch loss 0.639335513
# Epoch 3 val loss 0.58171147108078
# Model ./models/model-epoch-3-loss-0.5817.h5 saved.
# Start epoch 4 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.594941139 epoch total loss 0.560742736
# Trained batch 200 batch loss 0.644978285 epoch total loss 0.576505423
# Trained batch 300 batch loss 0.510183573 epoch total loss 0.580050528
# Trained batch 400 batch loss 0.559521914 epoch total loss 0.577766478
# Trained batch 500 batch loss 0.582010806 epoch total loss 0.579676
# Trained batch 600 batch loss 0.603021622 epoch total loss 0.578816
# Trained batch 700 batch loss 0.513697565 epoch total loss 0.579206407
# Trained batch 800 batch loss 0.56193471 epoch total loss 0.57484442
# Trained batch 900 batch loss 0.575187 epoch total loss 0.57450968
# Trained batch 1000 batch loss 0.447766125 epoch total loss 0.574443519
# Trained batch 1100 batch loss 0.646022737 epoch total loss 0.575157344
# Trained batch 1200 batch loss 0.556081057 epoch total loss 0.576082468
# Trained batch 1300 batch loss 0.51422596 epoch total loss 0.576005816
# Trained batch 1400 batch loss 0.569055676 epoch total loss 0.57705003
# Trained batch 1500 batch loss 0.556026697 epoch total loss 0.577513695
# Trained batch 1600 batch loss 0.556697071 epoch total loss 0.575916052
# Trained batch 1700 batch loss 0.545806408 epoch total loss 0.575826049
# Trained batch 1800 batch loss 0.571629167 epoch total loss 0.575287521
# Trained batch 1900 batch loss 0.441603422 epoch total loss 0.575457692
# Trained batch 2000 batch loss 0.666227698 epoch total loss 0.575651228
# Trained batch 2100 batch loss 0.520923674 epoch total loss 0.57567215
# Trained batch 2200 batch loss 0.531752 epoch total loss 0.575298965
# Trained batch 2300 batch loss 0.397963 epoch total loss 0.574877262
# Trained batch 2400 batch loss 0.601319551 epoch total loss 0.574613929
# Trained batch 2500 batch loss 0.608427584 epoch total loss 0.575497329
# Trained batch 2600 batch loss 0.549574614 epoch total loss 0.57517767
# Trained batch 2700 batch loss 0.600306511 epoch total loss 0.574771404
# Epoch 4 train loss 0.5742288827896118
# Validated batch 100 batch loss 0.48011449
# Validated batch 200 batch loss 0.378737181
# Validated batch 300 batch loss 0.552794218
# Validated batch 400 batch loss 0.599483609
# Validated batch 500 batch loss 0.405107975
# Validated batch 600 batch loss 0.594106734
# Validated batch 700 batch loss 0.712175608
# Validated batch 800 batch loss 0.711723804
# Validated batch 900 batch loss 0.606420279
# Validated batch 1000 batch loss 0.548346758
# Validated batch 1100 batch loss 0.650046349
# Validated batch 1200 batch loss 0.584595799
# Validated batch 1300 batch loss 0.578016758
# Validated batch 1400 batch loss 0.633284032
# Validated batch 1500 batch loss 0.623764753
# Validated batch 1600 batch loss 0.551208615
# Validated batch 1700 batch loss 0.453473151
# Validated batch 1800 batch loss 0.625886
# Validated batch 1900 batch loss 0.542756557
# Validated batch 2000 batch loss 0.50703752
# Validated batch 2100 batch loss 0.585682511
# Validated batch 2200 batch loss 0.508896828
# Validated batch 2300 batch loss 0.673174858
# Validated batch 2400 batch loss 0.54091531
# Validated batch 2500 batch loss 0.534506679
# Validated batch 2600 batch loss 0.576766551
# Validated batch 2700 batch loss 0.446231753
# Epoch 4 val loss 0.5680158734321594
# Model ./models/model-epoch-4-loss-0.5680.h5 saved.
# Start epoch 5 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.544428587 epoch total loss 0.567582428
# Trained batch 200 batch loss 0.53533262 epoch total loss 0.563913167
# Trained batch 300 batch loss 0.542045236 epoch total loss 0.562830687
# Trained batch 400 batch loss 0.543403387 epoch total loss 0.566272497
# Trained batch 500 batch loss 0.474181443 epoch total loss 0.562267601
# Trained batch 600 batch loss 0.552577853 epoch total loss 0.561723351
# Trained batch 700 batch loss 0.511065543 epoch total loss 0.562400877
# Trained batch 800 batch loss 0.567417622 epoch total loss 0.561276555
# Trained batch 900 batch loss 0.523628 epoch total loss 0.561914623
# Trained batch 1000 batch loss 0.573151886 epoch total loss 0.560584128
# Trained batch 1100 batch loss 0.562167883 epoch total loss 0.560720325
# Trained batch 1200 batch loss 0.536630034 epoch total loss 0.560723901
# Trained batch 1300 batch loss 0.624006629 epoch total loss 0.559643149
# Trained batch 1400 batch loss 0.620784938 epoch total loss 0.56017524
# Trained batch 1500 batch loss 0.569027543 epoch total loss 0.559756696
# Trained batch 1600 batch loss 0.484530538 epoch total loss 0.559128881
# Trained batch 1700 batch loss 0.588744044 epoch total loss 0.557553411
# Trained batch 1800 batch loss 0.491000414 epoch total loss 0.5581159
# Trained batch 1900 batch loss 0.638321638 epoch total loss 0.558427095
# Trained batch 2000 batch loss 0.542461395 epoch total loss 0.55885303
# Trained batch 2100 batch loss 0.672102094 epoch total loss 0.558533192
# Trained batch 2200 batch loss 0.566449046 epoch total loss 0.558217883
# Trained batch 2300 batch loss 0.589883506 epoch total loss 0.558385968
# Trained batch 2400 batch loss 0.596479654 epoch total loss 0.557830393
# Trained batch 2500 batch loss 0.512782335 epoch total loss 0.557813227
# Trained batch 2600 batch loss 0.5720824 epoch total loss 0.557905793
# Trained batch 2700 batch loss 0.549377441 epoch total loss 0.558731556
# Epoch 5 train loss 0.559241533279419
# Validated batch 100 batch loss 0.647086143
# Validated batch 200 batch loss 0.577806115
# Validated batch 300 batch loss 0.588514924
# Validated batch 400 batch loss 0.614161253
# Validated batch 500 batch loss 0.420959532
# Validated batch 600 batch loss 0.567063928
# Validated batch 700 batch loss 0.531364799
# Validated batch 800 batch loss 0.598149538
# Validated batch 900 batch loss 0.399431676
# Validated batch 1000 batch loss 0.550861597
# Validated batch 1100 batch loss 0.620286822
# Validated batch 1200 batch loss 0.60858494
# Validated batch 1300 batch loss 0.57577157
# Validated batch 1400 batch loss 0.579948545
# Validated batch 1500 batch loss 0.565800369
# Validated batch 1600 batch loss 0.657296
# Validated batch 1700 batch loss 0.533258617
# Validated batch 1800 batch loss 0.633728623
# Validated batch 1900 batch loss 0.593226254
# Validated batch 2000 batch loss 0.661192417
# Validated batch 2100 batch loss 0.586498916
# Validated batch 2200 batch loss 0.689045668
# Validated batch 2300 batch loss 0.602206349
# Validated batch 2400 batch loss 0.542743385
# Validated batch 2500 batch loss 0.563685417
# Validated batch 2600 batch loss 0.574577
# Validated batch 2700 batch loss 0.635373056
# Epoch 5 val loss 0.5702566504478455
# Start epoch 6 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.462705553 epoch total loss 0.550193727
# Trained batch 200 batch loss 0.49310118 epoch total loss 0.540903509
# Trained batch 300 batch loss 0.532292187 epoch total loss 0.54166913
# Trained batch 400 batch loss 0.660516262 epoch total loss 0.544257343
# Trained batch 500 batch loss 0.532694638 epoch total loss 0.538844
# Trained batch 600 batch loss 0.547338128 epoch total loss 0.537464678
# Trained batch 700 batch loss 0.550735116 epoch total loss 0.537297606
# Trained batch 800 batch loss 0.543973625 epoch total loss 0.539457858
# Trained batch 900 batch loss 0.512023509 epoch total loss 0.541360676
# Trained batch 1000 batch loss 0.503281713 epoch total loss 0.539113224
# Trained batch 1100 batch loss 0.612689614 epoch total loss 0.540978909
# Trained batch 1200 batch loss 0.615031779 epoch total loss 0.543108225
# Trained batch 1300 batch loss 0.517635763 epoch total loss 0.543608606
# Trained batch 1400 batch loss 0.492371827 epoch total loss 0.54525423
# Trained batch 1500 batch loss 0.567906201 epoch total loss 0.543973923
# Trained batch 1600 batch loss 0.472270787 epoch total loss 0.544396579
# Trained batch 1700 batch loss 0.698432267 epoch total loss 0.543394864
# Trained batch 1800 batch loss 0.590454 epoch total loss 0.544900835
# Trained batch 1900 batch loss 0.618660331 epoch total loss 0.545281708
# Trained batch 2000 batch loss 0.510597587 epoch total loss 0.54526943
# Trained batch 2100 batch loss 0.594706178 epoch total loss 0.545193851
# Trained batch 2200 batch loss 0.624171734 epoch total loss 0.544510782
# Trained batch 2300 batch loss 0.636793792 epoch total loss 0.544599414
# Trained batch 2400 batch loss 0.616384745 epoch total loss 0.544977069
# Trained batch 2500 batch loss 0.596637845 epoch total loss 0.545209885
# Trained batch 2600 batch loss 0.515518606 epoch total loss 0.544839561
# Trained batch 2700 batch loss 0.615358412 epoch total loss 0.544968545
# Epoch 6 train loss 0.5446106791496277
# Validated batch 100 batch loss 0.448999703
# Validated batch 200 batch loss 0.364000142
# Validated batch 300 batch loss 0.550960422
# Validated batch 400 batch loss 0.536662221
# Validated batch 500 batch loss 0.529296756
# Validated batch 600 batch loss 0.416434884
# Validated batch 700 batch loss 0.591660619
# Validated batch 800 batch loss 0.67014116
# Validated batch 900 batch loss 0.432523251
# Validated batch 1000 batch loss 0.585663497
# Validated batch 1100 batch loss 0.613355935
# Validated batch 1200 batch loss 0.581676066
# Validated batch 1300 batch loss 0.559028506
# Validated batch 1400 batch loss 0.546243727
# Validated batch 1500 batch loss 0.574580431
# Validated batch 1600 batch loss 0.659428239
# Validated batch 1700 batch loss 0.487517059
# Validated batch 1800 batch loss 0.593915701
# Validated batch 1900 batch loss 0.452516317
# Validated batch 2000 batch loss 0.649558306
# Validated batch 2100 batch loss 0.602743506
# Validated batch 2200 batch loss 0.6282866
# Validated batch 2300 batch loss 0.557419658
# Validated batch 2400 batch loss 0.499374598
# Validated batch 2500 batch loss 0.483245492
# Validated batch 2600 batch loss 0.530533433
# Validated batch 2700 batch loss 0.551475585
# Epoch 6 val loss 0.5450559258460999
# Model ./models/model-epoch-6-loss-0.5451.h5 saved.
# Start epoch 7 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.50696826 epoch total loss 0.536584616
# Trained batch 200 batch loss 0.582172155 epoch total loss 0.539048195
# Trained batch 300 batch loss 0.410221457 epoch total loss 0.526103735
# Trained batch 400 batch loss 0.552796602 epoch total loss 0.527784288
# Trained batch 500 batch loss 0.640621901 epoch total loss 0.531039417
# Trained batch 600 batch loss 0.46855545 epoch total loss 0.531615138
# Trained batch 700 batch loss 0.631680369 epoch total loss 0.531044126
# Trained batch 800 batch loss 0.540056467 epoch total loss 0.530779064
# Trained batch 900 batch loss 0.524187088 epoch total loss 0.530042648
# Trained batch 1000 batch loss 0.44467023 epoch total loss 0.528961241
# Trained batch 1100 batch loss 0.701356053 epoch total loss 0.529329598
# Trained batch 1200 batch loss 0.538717628 epoch total loss 0.527289152
# Trained batch 1300 batch loss 0.668522656 epoch total loss 0.528606057
# Trained batch 1400 batch loss 0.47529006 epoch total loss 0.527579
# Trained batch 1500 batch loss 0.517556965 epoch total loss 0.528282166
# Trained batch 1600 batch loss 0.434509218 epoch total loss 0.528644681
# Trained batch 1700 batch loss 0.478138924 epoch total loss 0.528687298
# Trained batch 1800 batch loss 0.5645504 epoch total loss 0.528959513
# Trained batch 1900 batch loss 0.439191103 epoch total loss 0.528630197
# Trained batch 2000 batch loss 0.55052948 epoch total loss 0.528912127
# Trained batch 2100 batch loss 0.557872891 epoch total loss 0.529486656
# Trained batch 2200 batch loss 0.489400864 epoch total loss 0.530354321
# Trained batch 2300 batch loss 0.622993469 epoch total loss 0.530454755
# Trained batch 2400 batch loss 0.506274164 epoch total loss 0.53081274
# Trained batch 2500 batch loss 0.528230965 epoch total loss 0.53118962
# Trained batch 2600 batch loss 0.60523355 epoch total loss 0.532049477
# Trained batch 2700 batch loss 0.677440405 epoch total loss 0.531742156
# Epoch 7 train loss 0.5319864749908447
# Validated batch 100 batch loss 0.573093832
# Validated batch 200 batch loss 0.532912374
# Validated batch 300 batch loss 0.625337481
# Validated batch 400 batch loss 0.563513696
# Validated batch 500 batch loss 0.546090841
# Validated batch 600 batch loss 0.64871937
# Validated batch 700 batch loss 0.490265429
# Validated batch 800 batch loss 0.550111234
# Validated batch 900 batch loss 0.320036054
# Validated batch 1000 batch loss 0.492263436
# Validated batch 1100 batch loss 0.474644095
# Validated batch 1200 batch loss 0.532862723
# Validated batch 1300 batch loss 0.455248207
# Validated batch 1400 batch loss 0.58854121
# Validated batch 1500 batch loss 0.475191534
# Validated batch 1600 batch loss 0.550691187
# Validated batch 1700 batch loss 0.586053729
# Validated batch 1800 batch loss 0.607087731
# Validated batch 1900 batch loss 0.479516029
# Validated batch 2000 batch loss 0.44776094
# Validated batch 2100 batch loss 0.459275424
# Validated batch 2200 batch loss 0.58466804
# Validated batch 2300 batch loss 0.518454671
# Validated batch 2400 batch loss 0.455645919
# Validated batch 2500 batch loss 0.632900596
# Validated batch 2600 batch loss 0.530044317
# Validated batch 2700 batch loss 0.60087651
# Epoch 7 val loss 0.522986888885498
# Model ./models/model-epoch-7-loss-0.5230.h5 saved.
# Start epoch 8 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.491598547 epoch total loss 0.516861558
# Trained batch 200 batch loss 0.616276562 epoch total loss 0.520485878
# Trained batch 300 batch loss 0.533176899 epoch total loss 0.525420249
# Trained batch 400 batch loss 0.557053924 epoch total loss 0.522206128
# Trained batch 500 batch loss 0.48024413 epoch total loss 0.520642221
# Trained batch 600 batch loss 0.553811789 epoch total loss 0.518383563
# Trained batch 700 batch loss 0.512410879 epoch total loss 0.518486261
# Trained batch 800 batch loss 0.3697716 epoch total loss 0.518901587
# Trained batch 900 batch loss 0.685195327 epoch total loss 0.518800735
# Trained batch 1000 batch loss 0.576789498 epoch total loss 0.519842684
# Trained batch 1100 batch loss 0.497654825 epoch total loss 0.518907607
# Trained batch 1200 batch loss 0.552879453 epoch total loss 0.520281374
# Trained batch 1300 batch loss 0.598229587 epoch total loss 0.521676898
# Trained batch 1400 batch loss 0.584781528 epoch total loss 0.521559238
# Trained batch 1500 batch loss 0.496321559 epoch total loss 0.52073288
# Trained batch 1600 batch loss 0.487291455 epoch total loss 0.521263361
# Trained batch 1700 batch loss 0.531773686 epoch total loss 0.520141244
# Trained batch 1800 batch loss 0.558316708 epoch total loss 0.520176828
# Trained batch 1900 batch loss 0.465756178 epoch total loss 0.520535946
# Trained batch 2000 batch loss 0.49870643 epoch total loss 0.520088315
# Trained batch 2100 batch loss 0.55948025 epoch total loss 0.518950105
# Trained batch 2200 batch loss 0.546238959 epoch total loss 0.518661439
# Trained batch 2300 batch loss 0.360620499 epoch total loss 0.518651664
# Trained batch 2400 batch loss 0.565392613 epoch total loss 0.518375397
# Trained batch 2500 batch loss 0.501831412 epoch total loss 0.518121541
# Trained batch 2600 batch loss 0.470900476 epoch total loss 0.518486619
# Trained batch 2700 batch loss 0.549388289 epoch total loss 0.519181848
# Epoch 8 train loss 0.5194750428199768
# Validated batch 100 batch loss 0.569085
# Validated batch 200 batch loss 0.54150486
# Validated batch 300 batch loss 0.413115561
# Validated batch 400 batch loss 0.352940023
# Validated batch 500 batch loss 0.540582299
# Validated batch 600 batch loss 0.539755583
# Validated batch 700 batch loss 0.505892515
# Validated batch 800 batch loss 0.5240345
# Validated batch 900 batch loss 0.67663765
# Validated batch 1000 batch loss 0.538624644
# Validated batch 1100 batch loss 0.463432282
# Validated batch 1200 batch loss 0.556048691
# Validated batch 1300 batch loss 0.417537749
# Validated batch 1400 batch loss 0.563675284
# Validated batch 1500 batch loss 0.472844839
# Validated batch 1600 batch loss 0.53054744
# Validated batch 1700 batch loss 0.540357351
# Validated batch 1800 batch loss 0.418095946
# Validated batch 1900 batch loss 0.485417
# Validated batch 2000 batch loss 0.473315924
# Validated batch 2100 batch loss 0.477613151
# Validated batch 2200 batch loss 0.631524503
# Validated batch 2300 batch loss 0.452302843
# Validated batch 2400 batch loss 0.509871244
# Validated batch 2500 batch loss 0.483573139
# Validated batch 2600 batch loss 0.477305382
# Validated batch 2700 batch loss 0.573793054
# Epoch 8 val loss 0.5056329369544983
# Model ./models/model-epoch-8-loss-0.5056.h5 saved.
# Start epoch 9 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.511065781 epoch total loss 0.500131369
# Trained batch 200 batch loss 0.440635562 epoch total loss 0.509779632
# Trained batch 300 batch loss 0.504189193 epoch total loss 0.515463948
# Trained batch 400 batch loss 0.465695918 epoch total loss 0.509095728
# Trained batch 500 batch loss 0.54271841 epoch total loss 0.506033242
# Trained batch 600 batch loss 0.535471797 epoch total loss 0.504900694
# Trained batch 700 batch loss 0.523924768 epoch total loss 0.505496204
# Trained batch 800 batch loss 0.473943621 epoch total loss 0.506481767
# Trained batch 900 batch loss 0.579635203 epoch total loss 0.507133424
# Trained batch 1000 batch loss 0.455697715 epoch total loss 0.504641175
# Trained batch 1100 batch loss 0.462244809 epoch total loss 0.503649652
# Trained batch 1200 batch loss 0.543823 epoch total loss 0.501769483
# Trained batch 1300 batch loss 0.540924609 epoch total loss 0.502788484
# Trained batch 1400 batch loss 0.530662477 epoch total loss 0.502956867
# Trained batch 1500 batch loss 0.510347903 epoch total loss 0.504929245
# Trained batch 1600 batch loss 0.516293 epoch total loss 0.505024
# Trained batch 1700 batch loss 0.593438268 epoch total loss 0.50625807
# Trained batch 1800 batch loss 0.491225481 epoch total loss 0.506881893
# Trained batch 1900 batch loss 0.534277678 epoch total loss 0.50600791
# Trained batch 2000 batch loss 0.400762647 epoch total loss 0.505194
# Trained batch 2100 batch loss 0.487225354 epoch total loss 0.504924119
# Trained batch 2200 batch loss 0.583489597 epoch total loss 0.505637765
# Trained batch 2300 batch loss 0.573595285 epoch total loss 0.505313098
# Trained batch 2400 batch loss 0.366021097 epoch total loss 0.505602539
# Trained batch 2500 batch loss 0.529103 epoch total loss 0.505459368
# Trained batch 2600 batch loss 0.586052418 epoch total loss 0.506452918
# Trained batch 2700 batch loss 0.500407696 epoch total loss 0.506662846
# Epoch 9 train loss 0.5076245069503784
# Validated batch 100 batch loss 0.52338016
# Validated batch 200 batch loss 0.543059051
# Validated batch 300 batch loss 0.564178705
# Validated batch 400 batch loss 0.562463641
# Validated batch 500 batch loss 0.337922633
# Validated batch 600 batch loss 0.497379661
# Validated batch 700 batch loss 0.627534151
# Validated batch 800 batch loss 0.629679
# Validated batch 900 batch loss 0.528086722
# Validated batch 1000 batch loss 0.427547872
# Validated batch 1100 batch loss 0.56237793
# Validated batch 1200 batch loss 0.459303647
# Validated batch 1300 batch loss 0.495765984
# Validated batch 1400 batch loss 0.571382284
# Validated batch 1500 batch loss 0.57011354
# Validated batch 1600 batch loss 0.575808525
# Validated batch 1700 batch loss 0.487414271
# Validated batch 1800 batch loss 0.372615427
# Validated batch 1900 batch loss 0.534914613
# Validated batch 2000 batch loss 0.43631646
# Validated batch 2100 batch loss 0.478766471
# Validated batch 2200 batch loss 0.515193641
# Validated batch 2300 batch loss 0.581623793
# Validated batch 2400 batch loss 0.433209479
# Validated batch 2500 batch loss 0.600308
# Validated batch 2600 batch loss 0.505142748
# Validated batch 2700 batch loss 0.581858397
# Epoch 9 val loss 0.4952666461467743
# Model ./models/model-epoch-9-loss-0.4953.h5 saved.
# Start epoch 10 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 100 batch loss 0.576657593 epoch total loss 0.493680954
# Trained batch 200 batch loss 0.503236175 epoch total loss 0.497515857
# Trained batch 300 batch loss 0.491012514 epoch total loss 0.495476216
# Trained batch 400 batch loss 0.467074 epoch total loss 0.500189066
# Trained batch 500 batch loss 0.360711396 epoch total loss 0.50199163
# Trained batch 600 batch loss 0.561605275 epoch total loss 0.496632397
# Trained batch 700 batch loss 0.486476958 epoch total loss 0.496661276
# Trained batch 800 batch loss 0.365275055 epoch total loss 0.495533824
# Trained batch 900 batch loss 0.526588917 epoch total loss 0.496300459
# Trained batch 1000 batch loss 0.511169076 epoch total loss 0.495549619
# Trained batch 1100 batch loss 0.55132097 epoch total loss 0.496058732
# Trained batch 1200 batch loss 0.558486938 epoch total loss 0.496694803
# Trained batch 1300 batch loss 0.457271934 epoch total loss 0.498487085
# Trained batch 1400 batch loss 0.470302105 epoch total loss 0.499022871
# Trained batch 1500 batch loss 0.480374098 epoch total loss 0.497915804
# Trained batch 1600 batch loss 0.63391912 epoch total loss 0.496698767
# Trained batch 1700 batch loss 0.5050928 epoch total loss 0.495933264
# Trained batch 1800 batch loss 0.469210505 epoch total loss 0.49565348
# Trained batch 1900 batch loss 0.512140214 epoch total loss 0.494940579
# Trained batch 2000 batch loss 0.370744467 epoch total loss 0.494450331
# Trained batch 2100 batch loss 0.554156184 epoch total loss 0.494400293
# Trained batch 2200 batch loss 0.49319309 epoch total loss 0.495147109
# Trained batch 2300 batch loss 0.532123923 epoch total loss 0.49540326
# Trained batch 2400 batch loss 0.54185462 epoch total loss 0.495334417
# Trained batch 2500 batch loss 0.442741722 epoch total loss 0.49621129
# Trained batch 2600 batch loss 0.508452058 epoch total loss 0.496796042
# Trained batch 2700 batch loss 0.559456885 epoch total loss 0.496309847
# Epoch 10 train loss 0.4959385395050049
# Validated batch 100 batch loss 0.522496581
# Validated batch 200 batch loss 0.50885427
# Validated batch 300 batch loss 0.374203265
# Validated batch 400 batch loss 0.426660299
# Validated batch 500 batch loss 0.518449843
# Validated batch 600 batch loss 0.517177165
# Validated batch 700 batch loss 0.686537385
# Validated batch 800 batch loss 0.479898632
# Validated batch 900 batch loss 0.425485671
# Validated batch 1000 batch loss 0.547860384
# Validated batch 1100 batch loss 0.525790334
# Validated batch 1200 batch loss 0.511693239
# Validated batch 1300 batch loss 0.542685509
# Validated batch 1400 batch loss 0.434683502
# Validated batch 1500 batch loss 0.537879109
# Validated batch 1600 batch loss 0.492619455
# Validated batch 1700 batch loss 0.576458812
# Validated batch 1800 batch loss 0.510756552
# Validated batch 1900 batch loss 0.462610096
# Validated batch 2000 batch loss 0.445800751
# Validated batch 2100 batch loss 0.407836735
# Validated batch 2200 batch loss 0.556994915
# Validated batch 2300 batch loss 0.462919444
# Validated batch 2400 batch loss 0.494515836
# Validated batch 2500 batch loss 0.603201151
# Validated batch 2600 batch loss 0.545342147
# Validated batch 2700 batch loss 0.443419516
# Epoch 10 val loss 0.4870864152908325
# Model ./models/model-epoch-10-loss-0.4871.h5 saved.

# %% [markdown]
# # 모델 시험 & 시각화

# %%
image, keypoints = predict(hg_model, TEST_IMAGE)
draw_keypoints_on_image(image, keypoints)
draw_skeleton_on_image(image, keypoints)

# %%
image, keypoints = predict(sb_model, TEST_IMAGE)
draw_keypoints_on_image(image, keypoints)
draw_skeleton_on_image(image, keypoints)

# %%
draw_history(hg_history_map, sb_history_map)

# %% [markdown]
# # 결론

# %% [markdown]
# 데이터 준비, 모델 생성&훈련 코드는 LMS의 코드를 수정하여 사용하였다.
#
# Hourglass모델과 Simplebaseline모델의 결과 이미지와 훈련 추이를 보면 대체로 비슷한 것을 볼 수 있다.
# 하지만 훈련 시간에 있어 Simplebaseline이 빨랐다.
# 모델 구현의 단순성에 있어서도 Simplebaseline이 월등히 단순하여 이해하기 쉬웠다.
#
# 손실의 절대값을 계산할 때 Hourglass는 4개의 stack을 구성하기 때문에 약 4배 큰 값을 가지게 된다.
# 또, 손실 추이의 비교를 위해 Hourglass의 손실 계산식을 Simplebaseline에도 동일하게 적용하였기 때문에
# 손실 크기의 절대값의 차이가 성능차이를 반영하지는 않는다.
#
# 최종 결과물을 시각적으로 확인하면 상당히 비슷한 정도의 성능을 가진다고 추정할 수 있다.
